# %%
# changed imports (Phase2)
import os
import uuid
import numpy as np
from PIL import Image
import tensorflow as tf
from tensorflow import keras

# new imports to phase 2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

from tensorflow.keras.optimizers import Adam
from SwarmPackagePy import gsa
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

import pandas as pd  # Import the Pandas library
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_curve, auc

# %%
train_dir = "..\isec-ic\\dataset\\train"
validation_dir = "..\isec-ic\\dataset\\valid"
test_dir = "..\isec-ic\\dataset\\test"

#output_dir = "results\\" # 10 classes (included earlyblight and targetspot)
output_dir = "base_results\\"  # excluded earlyblight and targetspot

current_dir = os.path.dirname(os.path.realpath(__file__ if '__file__' in locals() else os.getcwd()))

train_dir = os.path.join(current_dir, train_dir)
validation_dir = os.path.join(current_dir, validation_dir)
test_dir = os.path.join(current_dir, test_dir)
# , "earlyblight",  "targetspot"
categories = ["bacterialspot", "healthy",  "lateblight","leafmold", "mosaicvirus","yellowleafcurlvirus" ,"spidermite","septorialeafspot"]

# %%
def load_images_from_folder(folder):
    images = []
    labels = []
    subfolders = os.listdir(folder)  # list of subfolders in the main folder
    
    for subfolder in subfolders:
        category = subfolder.split("_")[-1].lower()  # category of the subfolder (e.g., "scab" from "Apple___Apple_scab")
        
        if category in categories:
            print("Loading images from category: " + category + " and subfolder: " + subfolder)
            subfolder_path = os.path.join(folder, subfolder)
            
            for filename in os.listdir(subfolder_path):
                img = Image.open(os.path.join(subfolder_path, filename))
                img = img.resize((64, 64)) # default is 256
                img = np.array(img) / 255.0  # normalization of the pixel values between 0 and 1
                images.append(img)
                labels.append(categories.index(category))  # index of the category in the list of categories
        else:
            print("Category: " + category + " from subfolder " + subfolder + " is not in the list of categories.")

    return np.array(images), np.array(labels)

# %%
x_train, y_train = load_images_from_folder(train_dir)
print("Finished to load the train images")

x_validation, y_validation = load_images_from_folder(validation_dir)
print("Finished to load the validation images")

x_test, y_test = load_images_from_folder(test_dir)
print("Finished to load the test images");
# Out:
# Loading images from category: spidermite and subfolder: Tomato__spidermite
# Loading images from category: bacterialspot and subfolder: Tomato___Bacterialspot
# Category: earlyblight from subfolder Tomato___Earlyblight is not in the list of categories.
# Loading images from category: healthy and subfolder: Tomato___healthy
# Loading images from category: lateblight and subfolder: Tomato___Lateblight
# Loading images from category: leafmold and subfolder: Tomato___Leafmold
# Loading images from category: septorialeafspot and subfolder: Tomato___Septorialeafspot
# Category: targetspot from subfolder Tomato___Targetspot is not in the list of categories.
# Loading images from category: mosaicvirus and subfolder: Tomato___Tomato_mosaicvirus
# Loading images from category: yellowleafcurlvirus and subfolder: Tomato___Tomato_yellowleafcurlvirus
# Finished to load the train images
# Loading images from category: bacterialspot and subfolder: Tomato___Bacterialspot
# Category: earlyblight from subfolder Tomato___Earlyblight is not in the list of categories.
# Loading images from category: healthy and subfolder: Tomato___healthy
# Loading images from category: lateblight and subfolder: Tomato___Lateblight
# Loading images from category: leafmold and subfolder: Tomato___Leafmold
# Loading images from category: septorialeafspot and subfolder: Tomato___Septorialeafspot
# Loading images from category: spidermite and subfolder: Tomato___Spider_spidermite
# Category: targetspot from subfolder Tomato___Targetspot is not in the list of categories.
# Loading images from category: mosaicvirus and subfolder: Tomato___Tomato_mosaicvirus
# Loading images from category: yellowleafcurlvirus and subfolder: Tomato___Tomato_Yellowleafcurlvirus
# Finished to load the validation images
# Loading images from category: bacterialspot and subfolder: tomato_bacterialspot
# Category: earlyblight from subfolder tomato_earlyblight is not in the list of categories.
# Loading images from category: healthy and subfolder: tomato_healthy
# Loading images from category: lateblight and subfolder: tomato_lateblight
# Loading images from category: leafmold and subfolder: tomato_leafmold
# Loading images from category: mosaicvirus and subfolder: tomato_mosaicvirus
# Loading images from category: septorialeafspot and subfolder: tomato_Septorialeafspot
# Loading images from category: spidermite and subfolder: tomato_spidermite
# Category: targetspot from subfolder tomato_targetspot is not in the list of categories.
# Loading images from category: yellowleafcurlvirus and subfolder: tomato_yellowleafcurlvirus
# Finished to load the test images

# %%
total_epochs = 10
model_uuid = uuid.uuid4()
learning_rate = 0.001
optimizer_name = "adam"
loss_function = "sparse_categorical_crossentropy"
size_img = "64x64"

# Display the total number of images loaded
print("Number of training images: " + str(len(x_train)))
print("Number of validation images: " + str(len(x_validation)))
print("Number of test images: " + str(len(x_test)))

optimizer = Adam(learning_rate=learning_rate)
# Out:
# Number of training images: 12000
# Number of validation images: 3200
# Number of test images: 800

# %%
from SwarmPackagePy import gsa

# Função de avaliação para o GSA
def evaluate_model_GSA(solution):
    num_layers, num_neurons = solution
    num_layers = max(1, round(num_layers))  # Garante que o número de camadas é pelo menos 1 e é um número arredondado
    num_neurons = max(1, round(num_neurons))  # Garante que o número de neurônios é pelo menos 1 e é um número arredondado

    activation_function = 'elu'  # ou escolha a função de ativação desejada
    learning_rate = 0.001

    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(64, 64, 3)),
    ])

    for _ in range(num_layers):
        model.add(keras.layers.Dense(num_neurons, activation=activation_function))

    model.add(keras.layers.Dense(8, activation='softmax'))

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
    
    try:
        model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        history = model.fit(x_train[:50], y_train[:50], epochs=5, validation_data=(x_validation[:25], y_validation[:25]), verbose=0)
        y_pred = np.argmax(model.predict(x_test[:25]), axis=1)
        accuracy = accuracy_score(y_test[:25], y_pred)

        return 1 - accuracy  # O GSA minimiza a função, então usamos 1 - accuracy
    except tf.errors.ResourceExhaustedError:
        # Em caso de falta de memória, retorne um custo alto
        return 1e6

# Parâmetros do GSA
num_agents = 10
max_iter = 10
G0 = 100  # Constante gravitacional inicial
alpha = 20  # Coeficiente de escala
min_mass = 1  # Massa mínima permitida
bounds = [(1, 5), (32, 128)]  # Limites para número de camadas e neurônios

# Inicialização
agents = np.random.uniform(low=np.array([bound[0] for bound in bounds]), high=np.array([bound[1] for bound in bounds]), size=(num_agents, len(bounds)))
costs = np.array([evaluate_model_GSA(agent) for agent in agents])

# Iterações do GSA
for iteration in range(max_iter):
    # Atualização da massa
    masses = min_mass + (G0 / (1 + alpha * iteration)) * costs

    # Atualização da posição dos agentes
    forces = np.zeros_like(agents)
    for i in range(num_agents):
        for j in range(num_agents):
            if i != j:
                r = np.linalg.norm(agents[i] - agents[j])
                force = G0 * masses[i] * masses[j] * (agents[j] - agents[i]) / (r + 1e-8)
                forces[i] += force

# Melhor solução encontrada
best_solution = agents[np.argmin(costs)]
best_num_layers, best_num_neurons = best_solution

print("found the best solution and layers")

# %%
print("Melhores Parâmetros Encontrados:")
print("Número de Camadas:", best_num_layers)
print("Número de Neurônios por Camada:", best_num_neurons)
# Out:
# Melhores Parâmetros Encontrados:
# Número de Camadas: 2.781248346592073
# Número de Neurônios por Camada: 52.850699216721495

# %%
total_epochs = 100

def create_model(num_layers, num_neurons):
    activation_function = 'elu'  # ou escolha a função de ativação desejada
    learning_rate = 0.001

    model = keras.Sequential([
        keras.layers.Flatten(input_shape=(64, 64, 3)),
    ])

    for _ in range(num_layers):
        model.add(keras.layers.Dense(num_neurons, activation=activation_function))

    model.add(keras.layers.Dense(8, activation='softmax'))

    return model

# Criar um novo modelo com os melhores 
best_model = create_model(int(best_num_layers), int(best_num_neurons))

# Compilar e treinar o modelo com os dados
best_model.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy']) # AQUI ADICIONAR MAIS METRICAS , F-UCS E O CRL
best_history = best_model.fit(x_train, y_train, epochs=total_epochs, validation_data=(x_validation, y_validation))

# Avaliar o desempenho do modelo treinado
best_train_accuracy = best_history.history['accuracy'][-1]
best_validation_accuracy = best_history.history['val_accuracy'][-1]

print("Melhor Accuracy de Treinamento:", best_train_accuracy)
print("Melhor Accuracy de Validação:", best_validation_accuracy)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.0602 - accuracy: 0.2733 - val_loss: 1.7600 - val_accuracy: 0.3462
# Epoch 2/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.6110 - accuracy: 0.3876 - val_loss: 1.5457 - val_accuracy: 0.3819
# Epoch 3/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.3893 - accuracy: 0.4660 - val_loss: 1.3369 - val_accuracy: 0.4925
# Epoch 4/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.3151 - accuracy: 0.4876 - val_loss: 1.3085 - val_accuracy: 0.4875
# Epoch 5/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2712 - accuracy: 0.4972 - val_loss: 1.2317 - val_accuracy: 0.5091
# Epoch 6/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2556 - accuracy: 0.5034 - val_loss: 1.2613 - val_accuracy: 0.4844
# Epoch 7/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2401 - accuracy: 0.5094 - val_loss: 1.2436 - val_accuracy: 0.5337
# Epoch 8/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2188 - accuracy: 0.5142 - val_loss: 1.2450 - val_accuracy: 0.4884
# Epoch 9/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2042 - accuracy: 0.5216 - val_loss: 1.2089 - val_accuracy: 0.5109
# Epoch 10/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.2063 - accuracy: 0.5128 - val_loss: 1.3114 - val_accuracy: 0.4825
# Epoch 11/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1992 - accuracy: 0.5155 - val_loss: 1.2624 - val_accuracy: 0.4944
# Epoch 12/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1696 - accuracy: 0.5247 - val_loss: 1.1669 - val_accuracy: 0.5462
# Epoch 13/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1925 - accuracy: 0.5163 - val_loss: 1.1955 - val_accuracy: 0.5100
# Epoch 14/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1714 - accuracy: 0.5252 - val_loss: 1.1574 - val_accuracy: 0.5178
# Epoch 15/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1320 - accuracy: 0.5397 - val_loss: 1.1688 - val_accuracy: 0.5113
# Epoch 16/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1148 - accuracy: 0.5609 - val_loss: 1.0957 - val_accuracy: 0.5731
# Epoch 17/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1226 - accuracy: 0.5504 - val_loss: 1.2220 - val_accuracy: 0.4947
# Epoch 18/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1299 - accuracy: 0.5351 - val_loss: 1.1396 - val_accuracy: 0.5247
# Epoch 19/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1167 - accuracy: 0.5420 - val_loss: 1.1674 - val_accuracy: 0.5134
# Epoch 20/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1130 - accuracy: 0.5407 - val_loss: 1.1282 - val_accuracy: 0.5309
# Epoch 21/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1071 - accuracy: 0.5428 - val_loss: 1.1386 - val_accuracy: 0.5225
# Epoch 22/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1003 - accuracy: 0.5471 - val_loss: 1.1464 - val_accuracy: 0.5269
# Epoch 23/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0971 - accuracy: 0.5505 - val_loss: 1.1905 - val_accuracy: 0.5019
# Epoch 24/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.1072 - accuracy: 0.5452 - val_loss: 1.1207 - val_accuracy: 0.5284
# Epoch 25/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0794 - accuracy: 0.5534 - val_loss: 1.1842 - val_accuracy: 0.5097
# Epoch 26/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0733 - accuracy: 0.5490 - val_loss: 1.1791 - val_accuracy: 0.5131
# Epoch 27/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0769 - accuracy: 0.5632 - val_loss: 1.1501 - val_accuracy: 0.5322
# Epoch 28/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0708 - accuracy: 0.5645 - val_loss: 1.1206 - val_accuracy: 0.5431
# Epoch 29/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0639 - accuracy: 0.5611 - val_loss: 1.1488 - val_accuracy: 0.5381
# Epoch 30/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0581 - accuracy: 0.5638 - val_loss: 1.1040 - val_accuracy: 0.5562
# Epoch 31/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0613 - accuracy: 0.5631 - val_loss: 1.0990 - val_accuracy: 0.5512
# Epoch 32/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0541 - accuracy: 0.5707 - val_loss: 1.1025 - val_accuracy: 0.5572
# Epoch 33/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0463 - accuracy: 0.5731 - val_loss: 1.1086 - val_accuracy: 0.5572
# Epoch 34/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0550 - accuracy: 0.5623 - val_loss: 1.1028 - val_accuracy: 0.5425
# Epoch 35/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0324 - accuracy: 0.5792 - val_loss: 1.1846 - val_accuracy: 0.5009
# Epoch 36/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0364 - accuracy: 0.5707 - val_loss: 1.1431 - val_accuracy: 0.5406
# Epoch 37/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0390 - accuracy: 0.5737 - val_loss: 1.1797 - val_accuracy: 0.5203
# Epoch 38/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0431 - accuracy: 0.5682 - val_loss: 1.0865 - val_accuracy: 0.5641
# Epoch 39/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0452 - accuracy: 0.5688 - val_loss: 1.2286 - val_accuracy: 0.5109
# Epoch 40/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0349 - accuracy: 0.5786 - val_loss: 1.1037 - val_accuracy: 0.5516
# Epoch 41/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0434 - accuracy: 0.5713 - val_loss: 1.1221 - val_accuracy: 0.5412
# Epoch 42/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0121 - accuracy: 0.5855 - val_loss: 1.0837 - val_accuracy: 0.5422
# Epoch 43/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0204 - accuracy: 0.5782 - val_loss: 1.0813 - val_accuracy: 0.5528
# Epoch 44/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0199 - accuracy: 0.5782 - val_loss: 1.0791 - val_accuracy: 0.5612
# Epoch 45/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0122 - accuracy: 0.5880 - val_loss: 1.0891 - val_accuracy: 0.5509
# Epoch 46/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0241 - accuracy: 0.5798 - val_loss: 1.1193 - val_accuracy: 0.5569
# Epoch 47/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0035 - accuracy: 0.5869 - val_loss: 1.0807 - val_accuracy: 0.5519
# Epoch 48/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9946 - accuracy: 0.5918 - val_loss: 1.1033 - val_accuracy: 0.5291
# Epoch 49/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0121 - accuracy: 0.5819 - val_loss: 1.3157 - val_accuracy: 0.4934
# Epoch 50/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0168 - accuracy: 0.5872 - val_loss: 1.0976 - val_accuracy: 0.5462
# Epoch 51/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9978 - accuracy: 0.5891 - val_loss: 1.1877 - val_accuracy: 0.5331
# Epoch 52/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0088 - accuracy: 0.5855 - val_loss: 1.1264 - val_accuracy: 0.5281
# Epoch 53/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9985 - accuracy: 0.5887 - val_loss: 1.0856 - val_accuracy: 0.5666
# Epoch 54/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0033 - accuracy: 0.5873 - val_loss: 1.1042 - val_accuracy: 0.5394
# Epoch 55/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9937 - accuracy: 0.5947 - val_loss: 1.0824 - val_accuracy: 0.5484
# Epoch 56/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.0542 - accuracy: 0.5862 - val_loss: 1.1384 - val_accuracy: 0.5328
# Epoch 57/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9896 - accuracy: 0.5964 - val_loss: 1.0765 - val_accuracy: 0.5553
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9726 - accuracy: 0.6036 - val_loss: 1.1485 - val_accuracy: 0.5366
# Epoch 59/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9941 - accuracy: 0.5928 - val_loss: 1.1335 - val_accuracy: 0.5450
# Epoch 60/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9757 - accuracy: 0.5959 - val_loss: 1.0820 - val_accuracy: 0.5663
# Epoch 61/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9924 - accuracy: 0.5918 - val_loss: 1.1011 - val_accuracy: 0.5409
# Epoch 62/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9905 - accuracy: 0.5926 - val_loss: 1.1226 - val_accuracy: 0.5497
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9695 - accuracy: 0.6008 - val_loss: 1.1378 - val_accuracy: 0.5400
# Epoch 64/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9734 - accuracy: 0.6027 - val_loss: 1.1137 - val_accuracy: 0.5522
# Epoch 65/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9689 - accuracy: 0.6070 - val_loss: 1.2283 - val_accuracy: 0.5206
# Epoch 66/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9795 - accuracy: 0.5942 - val_loss: 1.1294 - val_accuracy: 0.5272
# Epoch 67/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9669 - accuracy: 0.6033 - val_loss: 1.1029 - val_accuracy: 0.5459
# Epoch 68/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9807 - accuracy: 0.5976 - val_loss: 1.1065 - val_accuracy: 0.5484
# Epoch 69/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9719 - accuracy: 0.6015 - val_loss: 1.1439 - val_accuracy: 0.5322
# Epoch 70/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9670 - accuracy: 0.6018 - val_loss: 1.0877 - val_accuracy: 0.5587
# Epoch 71/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9577 - accuracy: 0.6075 - val_loss: 1.0917 - val_accuracy: 0.5525
# Epoch 72/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9519 - accuracy: 0.6077 - val_loss: 1.0778 - val_accuracy: 0.5581
# Epoch 73/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9579 - accuracy: 0.6090 - val_loss: 1.0864 - val_accuracy: 0.5638
# Epoch 74/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9629 - accuracy: 0.6046 - val_loss: 1.0788 - val_accuracy: 0.5528
# Epoch 75/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9468 - accuracy: 0.6122 - val_loss: 1.0900 - val_accuracy: 0.5587
# Epoch 76/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9564 - accuracy: 0.6086 - val_loss: 1.1060 - val_accuracy: 0.5462
# Epoch 77/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9484 - accuracy: 0.6089 - val_loss: 1.0984 - val_accuracy: 0.5587
# Epoch 78/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9610 - accuracy: 0.6081 - val_loss: 1.0908 - val_accuracy: 0.5609
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9568 - accuracy: 0.6091 - val_loss: 1.1097 - val_accuracy: 0.5503
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9494 - accuracy: 0.6109 - val_loss: 1.1671 - val_accuracy: 0.5297
# Epoch 81/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9662 - accuracy: 0.6048 - val_loss: 1.1136 - val_accuracy: 0.5416
# Epoch 82/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9396 - accuracy: 0.6179 - val_loss: 1.1672 - val_accuracy: 0.5387
# Epoch 83/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9470 - accuracy: 0.6071 - val_loss: 1.0811 - val_accuracy: 0.5653
# Epoch 84/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9410 - accuracy: 0.6147 - val_loss: 1.1058 - val_accuracy: 0.5559
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9519 - accuracy: 0.6064 - val_loss: 1.1351 - val_accuracy: 0.5350
# Epoch 86/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9383 - accuracy: 0.6109 - val_loss: 1.1379 - val_accuracy: 0.5497
# Epoch 87/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9443 - accuracy: 0.6128 - val_loss: 1.2126 - val_accuracy: 0.5066
# Epoch 88/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9356 - accuracy: 0.6181 - val_loss: 1.0848 - val_accuracy: 0.5491
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9481 - accuracy: 0.6089 - val_loss: 1.1198 - val_accuracy: 0.5559
# Epoch 90/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9296 - accuracy: 0.6189 - val_loss: 1.1565 - val_accuracy: 0.5512
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9245 - accuracy: 0.6243 - val_loss: 1.0797 - val_accuracy: 0.5591
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9528 - accuracy: 0.6075 - val_loss: 1.1196 - val_accuracy: 0.5525
# Epoch 93/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9386 - accuracy: 0.6140 - val_loss: 1.0730 - val_accuracy: 0.5531
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9192 - accuracy: 0.6215 - val_loss: 1.2254 - val_accuracy: 0.5194
# Epoch 95/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9284 - accuracy: 0.6199 - val_loss: 1.1412 - val_accuracy: 0.5337
# Epoch 96/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9349 - accuracy: 0.6185 - val_loss: 1.1439 - val_accuracy: 0.5516
# Epoch 97/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9243 - accuracy: 0.6220 - val_loss: 1.1474 - val_accuracy: 0.5359
# Epoch 98/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9172 - accuracy: 0.6238 - val_loss: 1.1243 - val_accuracy: 0.5453
# Epoch 99/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9461 - accuracy: 0.6113 - val_loss: 1.2351 - val_accuracy: 0.5138
# Epoch 100/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9233 - accuracy: 0.6173 - val_loss: 1.1452 - val_accuracy: 0.5509
# Melhor Accuracy de Treinamento: 0.6172500252723694
# Melhor Accuracy de Validação: 0.5509374737739563

# %%
# Plotar as curvas de treino e validação
plt.plot(best_history.history['accuracy'], label='Treinamento')
plt.plot(best_history.history['val_accuracy'], label='Validação')
plt.xlabel('Épocas')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
total_classes_name = f"{str(len(categories))}_classes"

y_pred = best_model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)

# Cálculo da precisão global (global accuracy)
global_accuracy = accuracy_score(y_test, y_pred_classes)
print("Global Accuracy: {:.2f}%".format(global_accuracy * 100))

file_name_confusion = f"{output_dir}{model_uuid}_confusion_matrix_{optimizer_name}_lr{learning_rate}_epochs{total_epochs}_.png"
file_name_precision = f"{output_dir}{model_uuid}_precision_{optimizer_name}_lr{learning_rate}_epochs{total_epochs}.png"
model_file_name = f"{output_dir}{global_accuracy}_{model_uuid}_model_{optimizer_name}_lr{learning_rate}_epochs{total_epochs}.keras"

# Confusion Matrix
confusion = confusion_matrix(y_test, y_pred_classes)
row_sums = confusion.sum(axis=1, keepdims=True)
percent_confusion = (confusion / row_sums) * 100
plt.figure(figsize=(8, 6))
sns.heatmap(percent_confusion, annot=True, fmt=".2f", cmap="Blues", xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.savefig(file_name_confusion)
plt.show()


# Precission report
classification = classification_report(y_test, y_pred_classes, target_names=categories, zero_division=1)
categories_classification = []
precision = []
lines = classification.split('\n')
for line in lines[2:-3]:
    parts = line.split()
    if len(parts) >= 4:
        category = parts[0]
        p = float(parts[3])
        categories_classification.append(category)
        precision.append(p)
plt.figure(figsize=(8, 6))
plt.bar(categories_classification, precision)
plt.xlabel('Classes')
plt.ylabel('Precisão')
plt.title('Precisão por Classe')
plt.xticks(rotation=45)
plt.savefig(file_name_precision) 
plt.show()

# Cálculo das métricas ROC-AUC, sensibilidade, especificidade, F-Measure e AUC
n_classes = len(categories)
fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(np.array([1 if j == i else 0 for j in y_test]), y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Convert the list of categories into a pandas Categorical object
categories_df = pd.Categorical(categories, categories=categories)

# Sensitivities, Specificities, F-Measures, and AUC
sensitivities = [tpr[i][0] for i in range(n_classes)]
specificities = [1 - fpr[i][0] for i in range(n_classes)]
f_measures = [2 * (s * p) / (s + p) for s, p in zip(sensitivities, specificities)]
roc_auc_values = [roc_auc[i] for i in range(n_classes)]

# Gráfico de Sensibilidade
plt.figure(figsize=(10, 6))
sns.barplot(x=categories_df, y=sensitivities)
plt.xlabel('Classes')
plt.ylabel('Sensibilidade')
plt.title('Sensibilidade por Classe')
plt.xticks(rotation=45)
plt.show()

# Gráfico de Especificidade
plt.figure(figsize=(10, 6))
sns.barplot(x=categories_df, y=specificities)
plt.xlabel('Classes')
plt.ylabel('Especificidade')
plt.title('Especificidade por Classe')
plt.xticks(rotation=45)
plt.show()

# Gráfico de F-Measure
plt.figure(figsize=(10, 6))
sns.barplot(x=categories_df, y=f_measures, errorbar='sd', capsize=0)  # Removido o cálculo do intervalo de confiança e as barras de erro
plt.xlabel('Classes')
plt.ylabel('F-Measure')
plt.title('F-Measure por Classe')
plt.xticks(rotation=45)
plt.show()

# Gráfico de AUC
plt.figure(figsize=(10, 6))
sns.barplot(x=categories_df, y=roc_auc_values)
plt.xlabel('Classes')
plt.ylabel('ROC-AUC')
plt.title('ROC-AUC por Classe')
plt.xticks(rotation=45)
plt.show()

# save the model 
best_model.save(model_file_name)
print("Model Saved Successfully: " + str(model_uuid));
# Out:
# 25/25 [==============================] - 0s 2ms/step
# Global Accuracy: 90.62%
# Model Saved Successfully: 2da56423-0638-48a6-a58d-83fa1a5e8fc4
